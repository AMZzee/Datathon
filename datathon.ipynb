# %% [markdown]
# Abdul Mannnan Zafar |
# PES University EC Campus |
# 4th Sem

# %%
import pandas as pd

# %%
import numpy as np

# %%
import random

# %%
df=pd.read_csv('data.csv')

# %%
df = df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1)

# %%
df.head
# Out:
# <bound method NDFrame.head of          MRP       SP                                              about  \
# 0      142.0   142.00  • Mr. Muscle floor cleaner comes with Glade Fr...
# 1      250.0   200.00  This winter.  choose silky smooth and soft ski...
# 2      899.0   598.91  The exceptional quality.  beautiful and unique...
# 3      753.0   549.69  Ocean Hi Ball Glass 370 ML Drinking Glasses - ...
# 4      125.0   106.25  A rich and creamy premium chocolate ice cream ...
# 5       70.0    69.00  Nature Clean is a 100% Herbal alternative to s...
# 6      120.0   120.00  The famous Dal Makhani of Delhi can now be coo...
# 7      300.0   300.00  A unique Product with IQF technology, Freshnes...
# 8      250.0   250.00  The mouth-watering spicy flavour of jalapenos ...
# 9      159.0   150.00  Figaro Peri Peri are red pickled chilies that ...
# 10     160.0   119.00  This MILTON  SPOTZERO Broom made from high qua...
# ...

# %%
df=df.dropna(subset=('SP',))

# %%
df
# Out:
#          MRP       SP                                              about  \
# 0      142.0   142.00  • Mr. Muscle floor cleaner comes with Glade Fr...
# 1      250.0   200.00  This winter.  choose silky smooth and soft ski...
# 2      899.0   598.91  The exceptional quality.  beautiful and unique...
# 3      753.0   549.69  Ocean Hi Ball Glass 370 ML Drinking Glasses - ...
# 4      125.0   106.25  A rich and creamy premium chocolate ice cream ...
# 5       70.0    69.00  Nature Clean is a 100% Herbal alternative to s...
# 6      120.0   120.00  The famous Dal Makhani of Delhi can now be coo...
# 7      300.0   300.00  A unique Product with IQF technology, Freshnes...
# 8      250.0   250.00  The mouth-watering spicy flavour of jalapenos ...
# 9      159.0   150.00  Figaro Peri Peri are red pickled chilies that ...
# 10     160.0   119.00  This MILTON  SPOTZERO Broom made from high qua...
# 11     213.0   159.75  James Smith Chicken ham is produced using chic...
# ...

# %%
df.loc['sku'] = df['sku'].fillna(lambda v: random.random() * 1000)

# %%
df['sku']
# Out:
# 0        40073473
# 1          266859
# 2        40126675
# 3        40086439
# 4        40008507
# 5        40006975
# 6        40096736
# 7        40112487
# 8        30010739
# 9        40065718
# 10       40102662
# 11       40094892
# 12       20003851
# 13       40022004
# 14       40118379
# 15       40126548
# 16       30002414
# 17       40080796
# 18       30005367
# 19       40134829
# 20      800205350
# 21       70001253
# 22       40109642
# 23       40114500
# 24       40016172
# 25       40026878
# 26       30010195
# 27       40042558
# 28       40127729
# 29       40098919
#           ...
# 9925     40113692
# 9926     40130593
# 9927     40104497
# 9928     40119158
# 9929     40126987
# 9930     40075042
# 9931     40061563
# 9932     40085122
# 9933     40120565
# 9934     40085117
# 9935     40123170
# 9936     60000022
# 9937     40069221
# 9938     40076752
# 9939     40038500
# 9940     40130590
# 9941     40050593
# 9942     40009488
# 9943    800389794
# ...

# %%
df = df.reset_index()
del df['index']
